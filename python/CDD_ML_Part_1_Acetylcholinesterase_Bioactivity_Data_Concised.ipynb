# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.12.14)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.3.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.17.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.0 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.1 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.0 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []    Drosophila melanogaster
# 1                []               Homo sapiens
# 2                []        Torpedo californica
# 3                []               Mus musculus
# 4                []          Rattus norvegicus
# 5                []   Electrophorus electricus
# 6                []                 Bos taurus
# 7                []             Bemisia tabaci
# 8                []  Leptinotarsa decemlineata
# 9                []     Nephotettix cincticeps
# 10               []              Gallus gallus
# 11               []                Danio rerio
# 12               []            Musca domestica
# 13               []          Anopheles gambiae
# 14               []               Homo sapiens
# 15               []        Plutella xylostella
# 16               []            Musca domestica
# 17               []  Pediculus humanus capitis
# 18               []          Spodoptera litura
# 19               []      Laodelphax striatella
# 20               []        Schizaphis graminum
# 21               []              Aedes aegypti
# 22               []          Rattus norvegicus
# 23               []     Caenorhabditis elegans
# 24               []             Equus caballus
# 25               []     Canis lupus familiaris
# 26               []               Mus musculus
# 27               []          Rattus norvegicus
# 28               []             Equus caballus
# 29               []               Homo sapiens
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   18.0
# 1                                Acetylcholinesterase   16.0
# 2                                Acetylcholinesterase   16.0
# 3                                Acetylcholinesterase   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   16.0
# 6                                Acetylcholinesterase   16.0
# 7                                               AChE2   16.0
# 8                                Acetylcholinesterase   16.0
# 9                Ace-orthologous acetylcholinesterase   16.0
# 10                               Acetylcholinesterase   16.0
# 11                               Acetylcholinesterase   16.0
# 12                               Acetylcholinesterase   15.0
# 13                               Acetylcholinesterase   15.0
# 14                       Cholinesterases; ACHE & BCHE   15.0
# 15                               Acetylcholinesterase   15.0
# 16                               Acetylcholinesterase   15.0
# 17                               Acetylcholinesterase   15.0
# 18                               Acetylcholinesterase   15.0
# 19                               Acetylcholinesterase   15.0
# 20                               Acetylcholinesterase   15.0
# 21                               Acetylcholinesterase   15.0
# 22  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 23                             Acetylcholinesterase 1   14.0
# 24                              Butyrylcholinesterase   11.0
# 25                                     Cholinesterase   11.0
# 26                              Butyrylcholinesterase   10.0
# 27                              Butyrylcholinesterase   10.0
# 28                                     Cholinesterase   10.0
# 29                              Butyrylcholinesterase    8.0
#
#     species_group_flag target_chembl_id  \
# 0                False    CHEMBL2242744
# 1                False        CHEMBL220
# 2                False       CHEMBL4780
# 3                False       CHEMBL3198
# 4                False       CHEMBL3199
# 5                False       CHEMBL4078
# 6                False       CHEMBL4768
# 7                False    CHEMBL2366409
# 8                False    CHEMBL2366490
# 9                False    CHEMBL2366514
# 10               False    CHEMBL3227914
# 11               False    CHEMBL3308995
# 12               False       CHEMBL5752
# 13               False    CHEMBL2046266
# 14               False    CHEMBL2095233
# 15               False    CHEMBL2242729
# 16               False    CHEMBL2242743
# 17               False    CHEMBL2362988
# 18               False    CHEMBL2366422
# 19               False    CHEMBL2366446
# 20               False    CHEMBL2366511
# 21               False    CHEMBL4295607
# 22               False    CHEMBL2111475
# 23               False    CHEMBL3341583
# 24               False       CHEMBL5077
# 25               False    CHEMBL4630814
# 26               False       CHEMBL2528
# 27               False       CHEMBL3403
# 28               False       CHEMBL5763
# 29               False       CHEMBL1914
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 15  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 23  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 24  [{'accession': 'Q9N1N9', 'component_descriptio...     SINGLE PROTEIN
# 25  [{'accession': 'P32750', 'component_descriptio...     SINGLE PROTEIN
# 26  [{'accession': 'Q03311', 'component_descriptio...     SINGLE PROTEIN
# 27  [{'accession': 'Q9JKC1', 'component_descriptio...     SINGLE PROTEIN
# 28  [{'accession': 'P81908', 'component_descriptio...     SINGLE PROTEIN
# 29  [{'accession': 'P06276', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     7227
# 1     9606
# 2     7787
# 3    10090
# 4    10116
# 5     8005
# 6     9913
# 7     7038
# 8     7539
# 9    94400
# 10    9031
# 11    7955
# 12    7370
# 13    7165
# 14    9606
# 15   51655
# 16    7370
# 17  121226
# 18   69820
# 19  195883
# 20   13262
# 21    7159
# 22   10116
# 23    6239
# 24    9796
# 25    9615
# 26   10090
# 27   10116
# 28    9796
# 29    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3199'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        32049                  []
# 1        None             None        32050                  []
# 2        None             None        34486                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 1    CHEMBL642842  Effect on Acetylcholinesterase activity in rat...
# 2    CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#      target_organism      target_pref_name target_tax_id text_value  toid  \
# 0  Rattus norvegicus  Acetylcholinesterase         10116       None  None
# 1  Rattus norvegicus  Acetylcholinesterase         10116       None  None
# 2  Rattus norvegicus  Acetylcholinesterase         10116       None  None
#
#   type units    uo_units upper_value value
# 0  I50    mM  UO_0000065        None   0.1
# 1  I50    mM  UO_0000065        None  0.17
# 2  I50    mM  UO_0000065        None   0.2
#
# [3 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! cp acetylcholinesterase_01_bioactivity_data_raw.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# acetylcholinesterase_01_bioactivity_data_raw.csv

# %%
! head acetylcholinesterase_01_bioactivity_data_raw.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,32049,[],CHEMBL642843,Effect on Acetylcholinesterase activity in rat erythrocytes,B,,,BAO_0000190,BAO_0000219,cell-based format,CC[N+](C)(CC)CC(=O)CCN1C(=O)CCC1=O.[I-],,,CHEMBL1123058,J Med Chem,1985,"{'bei': '15.67', 'le': '0.30', 'lle': '3.42', 'sei': '7.35'}",CHEMBL15886,,CHEMBL1178213,4.00,0,http://www.openphacts.org/units/Nanomolar,17693,=,1,1,=,,IC50,nM,,100000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.1
# ,,32050,[],CHEMBL642842,Effect on Acetylcholinesterase activity in rat brain homogenates,B,,,BAO_0000190,BAO_0000221,tissue-based format,CC[N+](C)(CC)CC(=O)CCN1C(=O)CCC1=O.[I-],Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1123058,J Med Chem,1985,,CHEMBL15886,,CHEMBL1178213,,0,http://www.openphacts.org/units/Nanomolar,17693,=,1,1,=,,IC50,nM,,170000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.17
# ,,34486,[],CHEMBL642843,Effect on Acetylcholinesterase activity in rat erythrocytes,B,,,BAO_0000190,BAO_0000219,cell-based format,C[n+]1ccccc1CCC(O)CCl.[I-],Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1123058,J Med Chem,1985,,CHEMBL556129,,CHEMBL1196197,,0,http://www.openphacts.org/units/Nanomolar,17691,=,1,1,=,,IC50,nM,,200000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.2
# ,,34487,[],CHEMBL642842,Effect on Acetylcholinesterase activity in rat brain homogenates,B,,,BAO_0000190,BAO_0000221,tissue-based format,C[n+]1ccccc1CCC(O)CCl.[I-],Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1123058,J Med Chem,1985,,CHEMBL556129,,CHEMBL1196197,,0,http://www.openphacts.org/units/Nanomolar,17691,=,1,1,=,,IC50,nM,,200000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.2
# ,,38116,[],CHEMBL642843,Effect on Acetylcholinesterase activity in rat erythrocytes,B,,,BAO_0000190,BAO_0000219,cell-based format,C[N+](C)(C)CCCCl.[Br-],Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1123058,J Med Chem,1985,,CHEMBL15795,,CHEMBL1178211,,0,http://www.openphacts.org/units/Nanomolar,17688,=,1,1,=,,IC50,nM,,260000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.26
# ,,38117,[],CHEMBL642842,Effect on Acetylcholinesterase activity in rat brain homogenates,B,,,BAO_0000190,BAO_0000221,tissue-based format,C[N+](C)(C)CCCCl.[Br-],Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1123058,J Med Chem,1985,,CHEMBL15795,,CHEMBL1178211,,0,http://www.openphacts.org/units/Nanomolar,17688,=,1,1,=,,IC50,nM,,260000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.26
# ,,41591,[],CHEMBL642843,Effect on Acetylcholinesterase activity in rat erythrocytes,B,,,BAO_0000190,BAO_0000219,cell-based format,BrCCCCCC[n+]1ccccc1.[Br-],,,CHEMBL1123058,J Med Chem,1985,"{'bei': '17.36', 'le': '0.44', 'lle': '1.29', 'sei': '108.81'}",CHEMBL276539,,CHEMBL1183031,4.22,0,http://www.openphacts.org/units/Nanomolar,17700,=,1,1,=,,IC50,nM,,60000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.06
# ,,41592,[],CHEMBL642842,Effect on Acetylcholinesterase activity in rat brain homogenates,B,,,BAO_0000190,BAO_0000221,tissue-based format,BrCCCCCC[n+]1ccccc1.[Br-],,,CHEMBL1123058,J Med Chem,1985,"{'bei': '16.64', 'le': '0.43', 'lle': '1.12', 'sei': '104.27'}",CHEMBL276539,,CHEMBL1183031,4.05,0,http://www.openphacts.org/units/Nanomolar,17700,=,1,1,=,,IC50,nM,,90000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.09
# ,,42915,[],CHEMBL642843,Effect on Acetylcholinesterase activity in rat erythrocytes,B,,,BAO_0000190,BAO_0000219,cell-based format,CC[N+](C)(CC)CCc1ccncc1.[I-],Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1123058,J Med Chem,1985,,CHEMBL278956,,CHEMBL1183085,,0,http://www.openphacts.org/units/Nanomolar,17696,=,1,1,=,,IC50,nM,,200000.0,CHEMBL3199,Rattus norvegicus,Acetylcholinesterase,10116,,,I50,mM,UO_0000065,,0.2

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      activity_comment  activity_id  ... upper_value value
# 0                None        33969  ...        None  0.75
# 1                None        37563  ...        None   0.1
# 2                None        37565  ...        None  50.0
# 3                None        38902  ...        None   0.3
# 4                None        41170  ...        None   0.8
# ...               ...          ...  ...         ...   ...
# 7021             None     18798886  ...        None  3.81
# 7022             None     18798887  ...        None  3.46
# 7023             None     18798888  ...        None  2.78
# 7024             None     18798889  ...        None  0.45
# 7025             None     18798890  ...        None  2.51
#
# [5835 rows x 43 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 4695

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  ... upper_value value
# 0                None        33969  ...        None  0.75
# 1                None        37563  ...        None   0.1
# 2                None        37565  ...        None  50.0
# 3                None        38902  ...        None   0.3
# 4                None        41170  ...        None   0.8
# ...               ...          ...  ...         ...   ...
# 7019             None     18798884  ...        None  2.44
# 7020             None     18798885  ...        None  2.54
# 7021             None     18798886  ...        None  3.81
# 7022             None     18798887  ...        None  3.46
# 7023             None     18798888  ...        None  2.78
#
# [4695 rows x 43 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id  ... standard_value
# 0          CHEMBL133897  ...          750.0
# 1          CHEMBL336398  ...          100.0
# 2          CHEMBL131588  ...        50000.0
# 3          CHEMBL130628  ...          300.0
# 4          CHEMBL130478  ...          800.0
# ...                 ...  ...            ...
# 7019      CHEMBL4293155  ...         2440.0
# 7020      CHEMBL4282558  ...         2540.0
# 7021      CHEMBL4281727  ...         3810.0
# 7022      CHEMBL4292349  ...         3460.0
# 7023      CHEMBL4278260  ...         2780.0
#
# [4695 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id  ...         class
# 0          CHEMBL133897  ...        active
# 1          CHEMBL336398  ...        active
# 2          CHEMBL131588  ...      inactive
# 3          CHEMBL130628  ...        active
# 4          CHEMBL130478  ...        active
# ...                 ...  ...           ...
# 4690      CHEMBL4293155  ...  intermediate
# 4691      CHEMBL4282558  ...  intermediate
# 4692      CHEMBL4281727  ...  intermediate
# 4693      CHEMBL4292349  ...  intermediate
# 4694      CHEMBL4278260  ...  intermediate
#
# [4695 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 90%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 4668
# -rw-r--r-- 1 root root 3562870 Jun  1 15:03 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  342989 Jun  1 15:03 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  385924 Jun  1 15:03 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  475843 Jun  1 15:03 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 May 27 16:27 sample_data

# %% [markdown]
# ---
